# %%
import os
from Cut import *
from CyClient import *
import matplotlib.pyplot as plt
target_dir = "pads55"
img_count = 0
cli = Client()

# %%
cli.sayHello()
# Out:
# received:  Hello From Server

# %%
img = cli.getPic()
plt.imshow(img)
plt.show()
# Out:
# received:
# 600 800 3
# 30000

# %%
def shot_one_pic(seris_name = ""):
    global img_count
    img = cli.getPic()
    
    img = get_Contour(img)
    cv2.imwrite(os.path.join(target_dir,seris_name+"%d.png" %img_count),img)
    img_count+=1
#     plt.imshow(img)
#     plt.show()
shot_one_pic("cutTemplate")
# Out:
# received:
# 600 800 3
# 30000
# 0.0

# %%
img_count = 0
